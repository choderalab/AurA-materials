# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import re
import seaborn as sns
from glob import glob
sns.set_style("white")
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/albaness/miniconda3/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
phos_data_tpx = glob('./data/distances/288-255/distances_AURKA_AURKA_phos_tpx2-*.npy')
nophos_data_tpx = glob('./data/distances/288-255/distances_AURKA_AURKA_nophos_tpx2-*.npy')
phos_data_notpx = glob('./data/distances/288-255/distances_AURKA_AURKA_phos_notpx2-*.npy')
nophos_data_notpx = glob('./data/distances/288-255/distances_AURKA_AURKA_nophos_notpx2-*.npy')

# %%
data_phos_tpx = np.load(phos_data_tpx[0])
data_nophos_tpx = np.load(nophos_data_tpx[0])
data_phos_notpx = np.load(phos_data_notpx[0])
data_nophos_notpx = np.load(nophos_data_notpx[0])

# %%
colors = ["amber","dark lavender","cerulean", "pale red"]

# %%
with sns.xkcd_palette(colors):
    plt.figure(figsize=(20,15), dpi=300)
    labels = []
    sns.distplot(data_phos_tpx,bins=None, norm_hist=True)
    labels.append('+Phos +TPX')
    sns.distplot(data_nophos_tpx,bins=None, norm_hist=True)
    labels.append('-Phos +TPX')
    sns.distplot(data_phos_notpx,bins=None, norm_hist=True)
    labels.append('+Phos -TPX')
    sns.distplot(data_nophos_notpx,bins=None, norm_hist=True)
    labels.append('-Phos -TPX')
    plt.title('%s-%s' % ('T288', 'R255'), fontsize=50)
    plt.legend(labels, fontsize=45);
    plt.xlabel('T288 $\\alpha$C - R255 Cz Distance ($\\AA$)', fontsize=40);
    plt.ylabel('probability', fontsize=45)
    plt.yticks([], fontsize=30);
    plt.xticks(fontsize=40)
    #plt.axvline(x=5, ymin=0, ymax=1, c='black', ls='--', linewidth=4)
    plt.xlim([2,14])
    plt.tight_layout()

    plt.savefig('t288-r255cz-all4.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
phos_data_tpx = glob('./data/distances/288-167/distances_AURKA_AURKA_phos_tpx2-*.npy')
nophos_data_tpx = glob('./data/distances/288-167/distances_AURKA_AURKA_nophos_tpx2-*.npy')
phos_data_notpx = glob('./data/distances/288-167/distances_AURKA_AURKA_phos_notpx2-*.npy')
nophos_data_notpx = glob('./data/distances/288-167/distances_AURKA_AURKA_nophos_notpx2-*.npy')
data_phos_tpx = np.load(phos_data_tpx[0])
data_nophos_tpx = np.load(nophos_data_tpx[0])
data_phos_notpx = np.load(phos_data_notpx[0])
data_nophos_notpx = np.load(nophos_data_notpx[0])

# %%
with sns.xkcd_palette(colors):
    plt.figure(figsize=(20,15), dpi=300)
    labels = []
    sns.distplot(data_phos_tpx,bins=None, norm_hist=True)
    labels.append('+Phos +TPX')
    sns.distplot(data_nophos_tpx,bins=None, norm_hist=True)
    labels.append('-Phos +TPX')
    sns.distplot(data_phos_notpx,bins=None, norm_hist=True)
    labels.append('+Phos -TPX')
    sns.distplot(data_nophos_notpx,bins=None, norm_hist=True)
    labels.append('-Phos -TPX')
    plt.title('%s-%s' % ('T288', 'A167'), fontsize=50)
    plt.legend(labels, fontsize=45);
    plt.xlabel('T288 $\\alpha$C - A167 $\\alpha$C  Distance ($\\AA$)', fontsize=40);
    plt.ylabel('probability', fontsize=45)
    plt.yticks([], fontsize=30);
    plt.xticks(fontsize=40)
    #plt.axvline(x=5, ymin=0, ymax=1, c='black', ls='--', linewidth=4)
    #plt.xlim([2,14])
    plt.tight_layout()
plt.savefig('t288-A167ca-all4.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
phos_data_tpx = glob('./data/distances/225-284/distances_AURKA_AURKA_phos_tpx2-*.npy')
nophos_data_tpx = glob('./data/distances/225-284/distances_AURKA_AURKA_nophos_tpx2-*.npy')
phos_data_notpx = glob('./data/distances/225-284/distances_AURKA_AURKA_phos_notpx2-*.npy')
nophos_data_notpx = glob('./data/distances/225-284/distances_AURKA_AURKA_nophos_notpx2-*.npy')
data_phos_tpx = np.load(phos_data_tpx[0])
data_nophos_tpx = np.load(nophos_data_tpx[0])
data_phos_notpx = np.load(phos_data_notpx[0])
data_nophos_notpx = np.load(nophos_data_notpx[0])
with sns.xkcd_palette(colors):
    plt.figure(figsize=(20,15), dpi=300)
    labels = []
    sns.distplot(data_phos_tpx,bins=None, norm_hist=True)
    labels.append('+Phos +TPX')
    sns.distplot(data_nophos_tpx,bins=None, norm_hist=True)
    labels.append('-Phos +TPX')
    sns.distplot(data_phos_notpx,bins=None, norm_hist=True)
    labels.append('+Phos -TPX')
    sns.distplot(data_nophos_notpx,bins=None, norm_hist=True)
    labels.append('-Phos -TPX')
    plt.title('%s-%s' % ('S284', 'L225'), fontsize=50)
    plt.legend(labels, fontsize=45)
    plt.xlabel('S284 $\\alpha$C - L225 $\\alpha$C Distance ($\\AA$)', fontsize=40);
    plt.ylabel('probability', fontsize=45)
    plt.yticks([], fontsize=30);
    plt.xticks(fontsize=40)
    #plt.xlim([2,14])
    plt.tight_layout()
plt.savefig('S284-L225ca-all4.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
colors = ["amber","dark lavender","cerulean", "pale red"]

# %%
colorp = sns.xkcd_palette(colors)
cmap = sns.light_palette(colorp[0], as_cmap=True)

# %%
t288_phos_tpx = np.load('./data/distances/288-255/distances_AURKA_AURKA_phos_tpx2-pair288-255.npy')
t288_nophos_tpx = np.load('./data/distances/288-255/distances_AURKA_AURKA_nophos_tpx2-pair288-255.npy')
t288_phos_notpx = np.load('./data/distances/288-255/distances_AURKA_AURKA_phos_notpx2-pair288-255.npy')
t288_nophos_notpx = np.load('./data/distances/288-255/distances_AURKA_AURKA_nophos_notpx2-pair288-255.npy')
s284_phos_tpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_phos_tpx2-pair225-284.npy')
s284_nophos_tpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_nophos_tpx2-pair225-284.npy')
s284_phos_notpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_phos_notpx2-pair225-284.npy')
s284_nophos_notpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_nophos_notpx2-pair225-284.npy')
plt.figure(figsize=(20,15), dpi=300)
labels = []
plt.subplot(2,2,1)
plt.hold(True)
cmap = sns.light_palette(colorp[0], as_cmap=True)
ax = sns.kdeplot(t288_phos_tpx, s284_phos_tpx, shaded=True, cmap=cmap)
plt.xlim([3,12])
plt.ylim([32,46])
plt.xlabel('T288 CA - R255 CZ Distance ($\\AA$)', fontsize=17)
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.title('+Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,2)
plt.hold(True)
cmap = sns.light_palette(colorp[1], as_cmap=True)
ax = sns.kdeplot(t288_nophos_tpx, s284_nophos_tpx, shaded=True, cmap=cmap)
plt.xlim([3,12])
plt.ylim([32,46])
plt.xlabel('T288 CA - R255 CZ Distance ($\\AA$)', fontsize=17)
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.title('-Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,3)
plt.hold(True)
cmap = sns.light_palette(colorp[2], as_cmap=True)
ax = sns.kdeplot(t288_phos_notpx, s284_phos_notpx, shaded=True, cmap=cmap)
plt.xlim([3,12])
plt.ylim([32,46])
plt.xlabel('T288 CA - R255 CZ Distance ($\\AA$)', fontsize=17)
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.title('+Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,4)
plt.hold(True)
cmap = sns.light_palette(colorp[3], as_cmap=True)
ax = sns.kdeplot(t288_nophos_notpx, s284_nophos_notpx, shaded=True, cmap=cmap)
labels.append('+Phos +TPX')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.xlim([3,12])
plt.ylim([32,46])
plt.xlabel('T288 CA - R255 CZ Distance ($\\AA$)', fontsize=17)
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.title('-Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.savefig('countourplot-284_225-288-255.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:12: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:23: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
# ...

# %%
phos_data_tpx = glob('./data/distances/288-180/distances_AURKA_AURKA_phos_tpx2-*.npy')
nophos_data_tpx = glob('./data/distances/288-180/distances_AURKA_AURKA_nophos_tpx2-*.npy')
phos_data_notpx = glob('./data/distances/288-180/distances_AURKA_AURKA_phos_notpx2-*.npy')
nophos_data_notpx = glob('./data/distances/288-180/distances_AURKA_AURKA_nophos_notpx2-*.npy')
data_phos_tpx = np.load(phos_data_tpx[0])
data_nophos_tpx = np.load(nophos_data_tpx[0])
data_phos_notpx = np.load(phos_data_notpx[0])
data_nophos_notpx = np.load(nophos_data_notpx[0])
with sns.xkcd_palette(colors):
    plt.figure(figsize=(20,15), dpi=300)
    labels = []
    sns.distplot(data_phos_tpx,bins=None, norm_hist=True)
    labels.append('+Phos +TPX')
    sns.distplot(data_nophos_tpx,bins=None, norm_hist=True)
    labels.append('-Phos +TPX')
    sns.distplot(data_phos_notpx,bins=None, norm_hist=True)
    labels.append('+Phos -TPX')
    sns.distplot(data_nophos_notpx,bins=None, norm_hist=True)
    labels.append('-Phos -TPX')
    plt.title('%s-%s' % ('T288', 'R180'), fontsize=50)
    plt.legend(labels, fontsize=45);
    plt.xlabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=40);
    plt.ylabel('probability', fontsize=45)
    plt.yticks([], fontsize=30);
    plt.xticks(fontsize=40)
    #plt.axvline(x=5, ymin=0, ymax=1, c='black', ls='--', linewidth=4)
    plt.xlim([2,25])
    plt.tight_layout()
plt.savefig('t288cb-r180cz-all4.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
colors = ["amber","dark lavender","cerulean", "pale red"]

# %%
t288_phos_tpx = np.load('./data/distances/288-255/distances_AURKA_AURKA_phos_tpx2-pair288-255.npy')
t288_nophos_tpx = np.load('./data/distances/288-255/distances_AURKA_AURKA_nophos_tpx2-pair288-255.npy')
t288_phos_notpx = np.load('./data/distances/288-255/distances_AURKA_AURKA_phos_notpx2-pair288-255.npy')
t288_nophos_notpx = np.load('./data/distances/288-255/distances_AURKA_AURKA_nophos_notpx2-pair288-255.npy')
r180_phos_tpx = np.load('./data/distances/288-180/distances_AURKA_AURKA_phos_tpx2-pair288-180.npy')
r180_nophos_tpx = np.load('./data/distances/288-180/distances_AURKA_AURKA_nophos_tpx2-pair288-180.npy')
r180_phos_notpx = np.load('./data/distances/288-180/distances_AURKA_AURKA_phos_notpx2-pair288-180.npy')
r180_nophos_notpx = np.load('./data/distances/288-180/distances_AURKA_AURKA_nophos_notpx2-pair288-180.npy')
plt.figure(figsize=(20,15), dpi=300)
labels = []
plt.subplot(2,2,1)
plt.hold(True)
cmap = sns.light_palette(colorp[0], as_cmap=True)
ax = sns.kdeplot(t288_phos_tpx, r180_phos_tpx, shaded=True, cmap=cmap)
plt.xlim([3,12])
plt.ylim([5,25])
plt.xlabel('T288 CA - R255 CZ Distance ($\\AA$)', fontsize=17)
plt.ylabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=17)
plt.title('+Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,2)
plt.hold(True)
cmap = sns.light_palette(colorp[1], as_cmap=True)
ax = sns.kdeplot(t288_nophos_tpx, r180_nophos_tpx, shaded=True, cmap=cmap)
plt.xlim([3,12])
plt.ylim([5,25])
plt.xlabel('T288 CA - R255 CZ Distance ($\\AA$)', fontsize=17)
plt.ylabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=17)
plt.title('-Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,3)
plt.hold(True)
cmap = sns.light_palette(colorp[2], as_cmap=True)
ax = sns.kdeplot(t288_phos_notpx, r180_phos_notpx, shaded=True, cmap=cmap)
plt.xlim([3,12])
plt.ylim([5,25])
plt.xlabel('T288 CA - R255 CZ Distance ($\\AA$)', fontsize=17)
plt.ylabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=17)
plt.title('+Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,4)
plt.hold(True)
cmap = sns.light_palette(colorp[3], as_cmap=True)
ax = sns.kdeplot(t288_nophos_notpx, r180_nophos_notpx, shaded=True, cmap=cmap)
labels.append('+Phos +TPX')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.xlim([3,12])
plt.ylim([5,25])
plt.xlabel('T288 CA - R255 CZ Distance ($\\AA$)', fontsize=17)
plt.ylabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=17)
plt.title('-Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.savefig('countourplots_t288cbr180.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:12: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:23: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
# ...

# %%
t288_phos_tpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_phos_tpx2-pair225-284.npy')
t288_nophos_tpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_nophos_tpx2-pair225-284.npy')
t288_phos_notpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_phos_notpx2-pair225-284.npy')
t288_nophos_notpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_nophos_notpx2-pair225-284.npy')
r180_phos_tpx = np.load('./data/distances/288-180/distances_AURKA_AURKA_phos_tpx2-pair288-180.npy')
r180_nophos_tpx = np.load('./data/distances/288-180/distances_AURKA_AURKA_nophos_tpx2-pair288-180.npy')
r180_phos_notpx = np.load('./data/distances/288-180/distances_AURKA_AURKA_phos_notpx2-pair288-180.npy')
r180_nophos_notpx = np.load('./data/distances/288-180/distances_AURKA_AURKA_nophos_notpx2-pair288-180.npy')
colors = ["amber","dark lavender","cerulean", "pale red"]
colorp = sns.xkcd_palette(colors)
cmap = sns.light_palette(colorp[0], as_cmap=True)
plt.figure(figsize=(20,15), dpi=300)
labels = []
plt.subplot(2,2,1)
plt.hold(True)
cmap = sns.light_palette(colorp[0], as_cmap=True)
ax = sns.kdeplot(r180_phos_tpx, t288_phos_tpx, shaded=True, cmap=cmap)
plt.ylim([30,46])
plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=17)
plt.title('+Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,2)
plt.hold(True)
cmap = sns.light_palette(colorp[1], as_cmap=True)
ax = sns.kdeplot(r180_nophos_tpx, t288_nophos_tpx, shaded=True, cmap=cmap)
plt.ylim([30,46])
plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=17)
plt.title('-Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,3)
plt.hold(True)
cmap = sns.light_palette(colorp[2], as_cmap=True)
ax = sns.kdeplot(r180_phos_notpx, t288_phos_notpx, shaded=True, cmap=cmap)
plt.ylim([30,46])
plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=17)
plt.title('+Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,4)
plt.hold(True)
cmap = sns.light_palette(colorp[3], as_cmap=True)
ax = sns.kdeplot(r180_nophos_notpx, t288_nophos_notpx, shaded=True, cmap=cmap)
labels.append('+Phos +TPX')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylim([30,46])
plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('T288 CB - R180 CZ Distance ($\\AA$)', fontsize=17)
plt.title('-Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.savefig('countourplots_s284car180.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:15: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:26: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
# ...

# %%
t288_phos_tpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_phos_tpx2-pair225-284.npy')
t288_nophos_tpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_nophos_tpx2-pair225-284.npy')
t288_phos_notpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_phos_notpx2-pair225-284.npy')
t288_nophos_notpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_nophos_notpx2-pair225-284.npy')
r180_phos_tpx = np.load('./data/dihedral/dihedral_AURKA_phos_tpx2-282-285.npy')
r180_nophos_tpx = np.load('./data/dihedral/dihedral_AURKA_nophos_tpx2-282-285.npy')
r180_phos_notpx = np.load('./data/dihedral/dihedral_AURKA_phos_notpx2-282-285.npy')
r180_nophos_notpx = np.load('./data/dihedral/dihedral_AURKA_nophos_notpx2-282-285.npy')
colors = ["amber","dark lavender","cerulean", "pale red"]
colorp = sns.xkcd_palette(colors)
cmap = sns.light_palette(colorp[0], as_cmap=True)
plt.figure(figsize=(20,15), dpi=300)
labels = []
plt.subplot(2,2,1)
plt.hold(True)
cmap = sns.light_palette(colorp[0], as_cmap=True)
ax = sns.kdeplot(r180_phos_tpx, t288_phos_tpx, shaded=True, cmap=cmap)
#plt.ylim([30,46])
#plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('Psuedodihedral 282-285 (Degrees)', fontsize=17)
plt.title('+Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,2)
plt.hold(True)
cmap = sns.light_palette(colorp[1], as_cmap=True)
ax = sns.kdeplot(r180_nophos_tpx, t288_nophos_tpx, shaded=True, cmap=cmap)
plt.ylim([30,46])
#plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('Psuedodihedral 282-285 (Degrees)', fontsize=17)
plt.title('-Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,3)
plt.hold(True)
cmap = sns.light_palette(colorp[2], as_cmap=True)
ax = sns.kdeplot(r180_phos_notpx, t288_phos_notpx, shaded=True, cmap=cmap)
plt.ylim([30,46])
#plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('Psuedodihedral 282-285 (Degrees)', fontsize=17)
plt.title('+Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,4)
plt.hold(True)
cmap = sns.light_palette(colorp[3], as_cmap=True)
ax = sns.kdeplot(r180_nophos_notpx, t288_nophos_notpx, shaded=True, cmap=cmap)
labels.append('+Phos +TPX')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylim([30,46])
#plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('Psuedodihedral 282-285 (Degrees)', fontsize=17)
plt.title('-Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.savefig('countourplots_s284-282-285dihedral.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:15: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:26: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
# ...

# %%
t288_phos_tpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_phos_tpx2-pair225-284.npy')
t288_nophos_tpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_nophos_tpx2-pair225-284.npy')
t288_phos_notpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_phos_notpx2-pair225-284.npy')
t288_nophos_notpx = np.load('./data/distances/225-284/distances_AURKA_AURKA_nophos_notpx2-pair225-284.npy')
r180_phos_tpx = np.load('./data/dihedral/dihedral_AURKA_phos_tpx2-283-286.npy')
r180_nophos_tpx = np.load('./data/dihedral/dihedral_AURKA_nophos_tpx2-283-286.npy')
r180_phos_notpx = np.load('./data/dihedral/dihedral_AURKA_phos_notpx2-283-286.npy')
r180_nophos_notpx = np.load('./data/dihedral/dihedral_AURKA_nophos_notpx2-283-286.npy')
colors = ["amber","dark lavender","cerulean", "pale red"]
colorp = sns.xkcd_palette(colors)
cmap = sns.light_palette(colorp[0], as_cmap=True)
plt.figure(figsize=(20,15), dpi=300)
labels = []
plt.subplot(2,2,1)
plt.hold(True)
cmap = sns.light_palette(colorp[0], as_cmap=True)
ax = sns.kdeplot(r180_phos_tpx, t288_phos_tpx, shaded=True, cmap=cmap)
#plt.ylim([30,46])
#plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('Psuedodihedral 283-286 (Degrees)', fontsize=17)
plt.title('+Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,2)
plt.hold(True)
cmap = sns.light_palette(colorp[1], as_cmap=True)
ax = sns.kdeplot(r180_nophos_tpx, t288_nophos_tpx, shaded=True, cmap=cmap)
plt.ylim([30,46])
#plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('Psuedodihedral 283-286 (Degrees)', fontsize=17)
plt.title('-Phos +TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,3)
plt.hold(True)
cmap = sns.light_palette(colorp[2], as_cmap=True)
ax = sns.kdeplot(r180_phos_notpx, t288_phos_notpx, shaded=True, cmap=cmap)
plt.ylim([30,46])
#plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('Psuedodihedral 283-286 (Degrees)', fontsize=17)
plt.title('+Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.subplot(2,2,4)
plt.hold(True)
cmap = sns.light_palette(colorp[3], as_cmap=True)
ax = sns.kdeplot(r180_nophos_notpx, t288_nophos_notpx, shaded=True, cmap=cmap)
labels.append('+Phos +TPX')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.ylim([30,46])
#plt.xlim([4,25])
plt.ylabel('S284 CA - L225 CA Distance ($\\AA$)', fontsize=17)
plt.xlabel('Psuedodihedral 283-286 (Degrees)', fontsize=17)
plt.title('-Phos -TPX2', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.savefig('countourplots_s284-283-286dihedral.pdf', transparent=True, dpi=300)
# Out:
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:15: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/albaness/miniconda3/lib/python3.5/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
# /Users/albaness/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:26: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
# ...
