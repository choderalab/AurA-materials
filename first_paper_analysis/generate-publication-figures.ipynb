# %%
# %matplotlib inline

import numpy as np
import sys
import math
import os
import time
import matplotlib.pyplot as plt
import seaborn

# %%
"""
Generate publication figures.

* Water presence/absence
* Fig 3B: Unnormalized autocorrelation functions for WT +/- Tpx2
* Fig 3C: Slow component of autocorrelation times and populations for mutants
* alphaC helix RMSD

"""

#hbond_basepath = '/cbio/jclab/projects/behrj/AURKA_UMN/'
hbond_basepath = 'data' # location of extracted trajectory features
output_basepath = 'figures'
nequil = 200 # number of frames to discard to equilibration (50 ns)

if not os.path.exists(output_basepath):
    os.makedirs(output_basepath)

# Parameters
nclones = 50 # number of CLONEs per RUN
projects = ['11414', '11419', '11418', '11423']
nruns = 7 # number of runs per project
resid = 185 # residue number used in constructing paths

# location of simulation data for each mutant
simulations = {
    '+Tpx2 WT' : [('11414', 'RUN0'), ('11419', 'RUN0'), ('11419', 'RUN1'), ('11419', 'RUN2'), ('11419', 'RUN3')],
    '+Tpx2 Q185C' : [('11414', 'RUN1')],
    '+Tpx2 Q185L' : [('11414', 'RUN2')],
    '+Tpx2 Q185M' : [('11414', 'RUN3')],
    '-Tpx2 WT' : [('11418', 'RUN0'), ('11418', 'RUN1'), ('11418', 'RUN2'), ('11418', 'RUN3'), ('11418', 'RUN4')],
    '-Tpx2 Q185C' : [('11423', 'RUN0')],
    '-Tpx2 Q185L' : [('11423', 'RUN1')],
    '-Tpx2 Q185M' : [('11423', 'RUN2')],
}

def squeeze_empty_trajectories(W):
    """
    Squeeze empty trajectories that are [None, ..., None] out from water set trajectories for W1 or W2.

    Parameters
    ----------
    W : np.array of dimension (ntraj, nframes)
        The trajectory to squeeze.

    Returns
    -------
    Wsqueezed : np.array of dimension (ntraj_squeezed, nframes)
        Squeezed version of W
    """
    non_empty_trajectories = list()
    for traj in range(W.shape[0]):
        if not np.all(np.equal(W[traj,:],  None)):
            non_empty_trajectories.append(traj)
    Wsqueezed = W[non_empty_trajectories,:]
    print('Squeezed out %d empty trajectories' % (W.shape[0] - Wsqueezed.shape[0]))
    return Wsqueezed

def retrieve_data(key):
    """
    Compile all available W1, W2 water set data for the specified simulation into a single array.

    Parameters
    ----------
    key : str
        The key into 'simulations' to identify projects and RUNs associated with the simulation data.

    Returns
    -------
    W1 : np.array shape (nsim, nsamples)
        Water 1 sets
    W2 : np.array shape (nsim, nsamples)
        Water 2 sets
    """
    print("Retrieving data for '%s'..." % key)
    [W1, W2] = [list(), list()]
    for (project,run) in simulations[key]:
        W1.append( np.load(os.path.join(hbond_basepath, 'output-%(project)s/data/%(run)s-274N-oxygen-indices.npy' % vars())) )
        W2.append( np.load(os.path.join(hbond_basepath, 'output-%(project)s/data/%(run)s-W2-181185-or275-oxygen-indices.npy' % vars())) )
    [W1, W2] = [np.vstack(W1), np.vstack(W2)]
    # Squeeze out rows that are just None
    [W1, W2] = [squeeze_empty_trajectories(W1), squeeze_empty_trajectories(W2)]
    return [W1, W2]

# %%
# Constuct binary arrays
def water_occupation_array(W):
    """
    Return an array that has a value of +1 if a water is present in that frame, 0 if not, -1 if no data due to truncated simulation.
    
    Parameters
    ----------
    W : np.array with shape (ntrajs,nframes)
        The water set trajectory
        
    Returns
    -------
    X : np.array with shape (ntrajs,nframes) dtype=np.float32
        X[traj,frame] = 1 if at least one water is present at the water site
                      = 0 if no water is present
                      = -1 if no simulation data available
    """
    X = np.zeros(W.shape, np.float32)
    [ntraj, nframe] = W.shape
    for traj in range(ntraj):
        for frame in range(nframe):
            if (W[traj,frame] is None):
                X[traj,frame] = -1
            elif (len(W[traj,frame]) > 0):
                X[traj,frame] = 1
    return X

# %%
def plot_water_occupancies(key, figsize=[20, 4.]):
    """
    Plot water occupancies for the specified key.
    
    Blue (-1) denotes no data; white (0) denotes no water; red (+1) denotes one or more waters present.
    
    Parameters
    ----------
    key : str
        The simulation key ['-Tpx2 WT', '+Tpx2 WT', '-Tpx2 Q185C', ...]
    figsize : list of len 2, optional
        The figure size to generate
            
    """

    # Retrieve data
    [W1, W2] = retrieve_data(key)

    fig = plt.figure(figsize=figsize)

    [ntrajs, nframes] = W1.shape
    
    plt.subplot(1,2,1);
    X1 = water_occupation_array(W1)
    plt.title('%s W1' % key);
    cax = plt.imshow(X1, extent=[0, nframes/4., 0, ntrajs], aspect='auto', cmap=plt.get_cmap('bwr'))
    cbar = fig.colorbar(cax, ticks=[-1, 0, 1])
    plt.xlabel('time / ns');
    plt.ylabel('trajectory');

    plt.subplot(1,2,2);
    X2 = water_occupation_array(W2)
    plt.title('%s W2' % key);
    cax = plt.imshow(X2, extent=[0, nframes/4., 0, ntrajs], aspect='auto', cmap=plt.get_cmap('bwr'))
    cbar = fig.colorbar(cax, ticks=[-1, 0, 1])
    plt.xlabel('time / ns');
    plt.ylabel('trajectory');

# %%
plot_water_occupancies('-Tpx2 WT')
plot_water_occupancies('+Tpx2 WT')
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories

# %%
plot_water_occupancies('-Tpx2 Q185C')
plot_water_occupancies('+Tpx2 Q185C')
# Out:
# Retrieving data for '-Tpx2 Q185C'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# Retrieving data for '+Tpx2 Q185C'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories

# %%
plot_water_occupancies('-Tpx2 Q185L')
plot_water_occupancies('+Tpx2 Q185L')
# Out:
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories

# %%
plot_water_occupancies('-Tpx2 Q185M')
plot_water_occupancies('+Tpx2 Q185M')
# Out:
# Retrieving data for '-Tpx2 Q185M'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# Retrieving data for '+Tpx2 Q185M'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories

# %%
ns_per_frame = 0.250 # nanoseconds per frame

def correlation_function_contributions(W, tmax=300, nequil=200):
    """
    Compute unnormalized correlation function contributions from each trajectory.
    
    Unnormalized correlation function:
        C(0) indicates water population at specified site
        C(tau) indicates same water at time 0 and time tau    

    Parameters
    ----------
    W : numpy.array shape (ntrajs,nframes)
        W[traj,frame] is the set of water oxygen indices present in the specified site at 'frame' of trajectory 'traj
    tmax : int, optional, default=250
        Maximum number of frames to compute correlation function for
    nequil : int, optional, default=200
        Number of frames to discard to equilibration
 
    Returns
    -------
    C : np.array with shape (ntrajs,tmax+1)
        C[traj,tau] is the unnormalized correlation function contribution from trajectory 'traj'
        Averaging over all trajectories will give the MLE, but this can also be bootstrapped to get uncertainties
        and confidence intervals.

    """
    [ntrajs, nframes] = W.shape
    C = np.zeros([ntrajs,tmax+1], np.float64)
    for traj in range(ntrajs):   
        Wtraj = W[traj,nequil:]
        nframes = np.sum(np.not_equal(Wtraj, None))
        for t in range(tmax+1):
            for t0 in range(nframes-t):
                same_waters = (len(Wtraj[t0].intersection(Wtraj[t0+t]))>0)
                C[traj,t] += same_waters / np.float(nframes-t)
    return C

def fit_correlation_function_tail(C, tmin):
    """
    Fit the tail of the correlation function.

    Parameters
    ----------
    C : np.array with shape (tmax+1,)
        C[tau] is the MLE for the unnormalized correlation function
    tmin : int
        Minimum time (in frames) to start curve fitting

    Returns
    -------
    P : float
        Population of long-lived waters
    tau : float
        Autocorrelation timescale for long-lived waters
    Cfit : np.array with shape (tmax+1,)
        Cfit[tau] is the fit of the correlation function tail

    """
    # Determine maximum time for correlation function
    tmax = C.shape[0] - 1 
    
    tvec = np.arange(tmax+1) * ns_per_frame # time vector (ns)
    tvec_indices = range(tmin,tmax+1)
    
    # Fit the correlation function tail
    from scipy.optimize import curve_fit
    def Cmodel(tvec, P, tau):
        return P*np.exp(-tvec/tau)
    
    popt, pcov = curve_fit(Cmodel, tvec[tvec_indices], C[tvec_indices], p0=[0.2, 50])    
    
    # Extract solution
    P = popt[0]
    tau = popt[1]
    
    # Compute fit
    Cfit = Cmodel(tvec, P, tau)

    return [P, tau, Cfit]

def sample_ci(data, interval=0.95):
    """
    Estimate confidence interval from a bootstrapped sample.
    
    Parameters
    ----------
    data : np.array of shape (nbootstrap,)
        The bootstrapped sample
    interval : float, optional, default=0.95
        The confidence interval size to compute
        
    Returns
    -------
    low_val, high_val : float
        The low and high confidence inverval estimates
        
    """
    import scipy as sp
    import scipy.stats

    sorted = np.sort(data)
    ndata = len(data)
    ilow = int(np.round((0.5-interval/2.)*ndata))
    ihigh = int(np.round((0.5+interval/2.)*ndata))
    ilow = min(ndata-1, ilow) # ensure within data range
    ihigh = min(ndata-1, ihigh) # ensure within data range
    return [sorted[ilow], sorted[ihigh]]

def correlation_function_statistics(C, ci=0.95, tmin=60, nbootstrap=10):
    """
    Compute unnormalized corelation function MLE and bootstrapped estimates.

    Parameters
    ----------
    C : np.array with shape (ntrajs,tmax+1)
        C[traj,tau] is the unnormalized correlation function contribution from trajectory 'traj'
        Averaging over all trajectories will give the MLE, but this can also be bootstrapped to get uncertainties
        and confidence intervals.
    ci : float, optional, default=0.95
        Size of confidence interval for bootstrapping
    tmin : int
        Minimum time (in frames) to start curve fitting
    nbootstrap : int
        Number of bootstrap samples to generate
        
    Returns
    -------
    tvec : np.array with shape (tmax+1,)
        time vector to accompany correlation functions
    C_mle : np.array with shape (tmax+1,)
        C[tau] is the MLE for the unnormalized correlation function
    C_low, C_high : np.array with shape (tmax+1,)
        Bootstrapped confidence interval for C(t) using confidence interval 'ci'
    Cfit_mle : np.array with shape (tmax+1,)
        Fit to correlation function tail for C_mle
    P_mle : float
        MLE estimate of population of long-lived water
    P_low, P_high : float
        Bootstrapped confidence interval for population of long-lived water
    tau_mle : float
        MLE estimate of slow decay timescale
    tau_low, tau_high : float
        Bootstrapped confidence interval for relaxation timescale of long-lived water population
    """
    ntrajs = C.shape[0]
    tmax = C.shape[1] - 1
    tvec = np.arange(tmax+1) * ns_per_frame # time vector (ns)
    
    # Compute maximum-likelihood estimators
    C_mle = C.mean(0)
    [P_mle, tau_mle, Cfit_mle] = fit_correlation_function_tail(C_mle, tmin=tmin)
    
    # Bootstrap
    C_n = np.zeros([nbootstrap, tmax+1], np.float32)
    P_n = np.zeros([nbootstrap], np.float64)
    tau_n = np.zeros([nbootstrap], np.float64)
    for bootstrap in range(nbootstrap):
        # Sample trajectories with replacement
        traj_indices = np.random.choice(range(ntrajs), size=ntrajs, replace=True)
        # Compute correlation function estimate
        C_replicate = C[traj_indices,:].mean(0)
        # Exponential fit to tail
        [P, tau, Cfit] = fit_correlation_function_tail(C_replicate, tmin=tmin)
        # Store
        C_n[bootstrap,:] = C_replicate
        P_n[bootstrap] = P
        tau_n[bootstrap] = tau

    # Compute statistics
    [P_low, P_high] = sample_ci(P_n, interval=ci)
    [tau_low, tau_high] = sample_ci(tau_n, interval=ci)
    C_low = 0.0 * C_mle
    C_high = 0.0 * C_mle    
    for tau in range(tmax+1):
        [C_low[tau], C_high[tau]] = sample_ci(C_n[:,tau], interval=ci)
        
    return [tvec, C_mle, Cfit_mle, C_low, C_high, P_mle, P_low, P_high, tau_mle, tau_low, tau_high]

# %%
# Compute per-trajectory correlation function contributions
tmax = 300 # 75 ns
C = dict()
for key in ['-Tpx2 WT', '+Tpx2 WT']:
    C[key] = dict()
    # Retrieve data for this project
    [W1, W2] = retrieve_data(key)
    # Compute trajectory contribtuions to correlation function
    C[key]['W1'] = correlation_function_contributions(W1, tmax=tmax)
    C[key]['W2'] = correlation_function_contributions(W2, tmax=tmax)
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories

# %%
# Plot trajectory contributions to correlation functions
fig = plt.figure(figsize=[20, 4.])

key = '-Tpx2 WT'
ntrajs = C[key]['W2'].shape[0]
tmax = C[key]['W2'].shape[1] - 1
tvec = np.arange(tmax+1) * ns_per_frame # time vector (ns)

plt.subplot(1,2,1);
plt.title('C(t) for W1');
cax = plt.imshow(C[key]['W1'], extent=[0, tmax/4., 0, ntrajs], aspect='auto', cmap=plt.get_cmap('bwr'))
#cbar = fig.colorbar(cax, ticks=[-1, 0, 1])
plt.xlabel('time / ns');
plt.ylabel('simulation');

plt.subplot(1,2,2);
plt.title('C(t) for W2');
cax = plt.imshow(C[key]['W2'], extent=[0, tmax/4., 0, ntrajs], aspect='auto', cmap=plt.get_cmap('bwr'))
#cbar = fig.colorbar(cax, ticks=[-1, 0, 1])
plt.xlabel('time / ns');
plt.ylabel('simulation');

plt.savefig('WT -Tpx2 individual trajectory contributions to correlation function.png')

# %%
# Produce Fig 3B
# WT -/+ Tpx2 W1 and W2 unnormalized autocorrelation functions with # Fig
import seaborn as sns
sns.set_style("white")

# Match sans serif text in LaTeX number rendering
params = {'text.usetex': False, 'mathtext.fontset': 'stixsans'}
plt.rcParams.update(params)

def plot_trace(C, handles, labels, name, color, marker):
    [tvec, C_mle, Cfit_mle, C_low, C_high, P_mle, P_low, P_high, tau_mle, tau_low, tau_high] = correlation_function_statistics(C, ci=0.95, tmin=60, nbootstrap=500)

    # Add plot
    h1 = plt.plot(tvec, Cfit_mle, marker, color=color, linewidth=0.5)
    h2 = plt.plot(tvec, C_mle, marker, color=color)
    # Add legend
    handles.append(h2[0])
    label = '%s: ${%.0f}_{%.0f}^{%.0f}$%% ; $\\tau$ = ${%.0f}_{%.0f}^{%.0f}$ ns' % (name, P_mle*100, P_low*100, P_high*100, tau_mle, tau_low, tau_high)
    labels.append(label)

# Plot MLE correlation function and exponential fit
fig = plt.figure(figsize=[2.75,2])
plt.legend()
plt.hold(True)
handles = list()
labels = list()
plot_trace(C['+Tpx2 WT']['W1'], handles, labels, name='W1 +Tpx2', color='#cc0099', marker='-')
plot_trace(C['+Tpx2 WT']['W2'], handles, labels, name='W2 +Tpx2', color='#cc0099', marker='--')
plot_trace(C['-Tpx2 WT']['W1'], handles, labels, name='W1 -Tpx2', color='#ff9966', marker='-')
plot_trace(C['-Tpx2 WT']['W2'], handles, labels, name='W2 -Tpx2', color='#ff9966', marker='--')
plt.legend(handles, labels, fontsize=6)
plt.axis([0, tvec[-1], 0, 1]);
plt.xlabel('time (ns)');
plt.ylabel('C(t)');
plt.xticks([0, 25, 50, 75])
sns.despine()
plt.tight_layout()
plt.savefig('Fig-3B.pdf')
# Out:
# /Users/choderaj/miniconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# Produce Fig 3C
# WT, Q185M, Q185L populations and correlation times +Tpx2

# Compute per-trajectory correlation function contributions
for key in ['+Tpx2 Q185M', '+Tpx2 Q185L']:
    C[key] = dict()
    # Retrieve data for this project
    [W1, W2] = retrieve_data(key)
    # Compute trajectory contribtuions to correlation function
    C[key]['W1'] = correlation_function_contributions(W1, tmax=tmax)
    C[key]['W2'] = correlation_function_contributions(W2, tmax=tmax)
# Out:
# Retrieving data for '+Tpx2 Q185M'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories

# %%
# Generate histogram
labels = list()
[taus, taus_low, taus_high] = [list(), list(), list()] # long-lived water lifetimes
[Ps, Ps_low, Ps_high] = [list(), list(), list()] # long-lived water populations
mutants = ['WT', 'Q185L', 'Q185M']
for mutant in mutants:
    key = '+Tpx2 %s' % mutant
    for wat in ['W1', 'W2']:
        [tvec, C_mle, Cfit_mle, C_low, C_high, P_mle, P_low, P_high, tau_mle, tau_low, tau_high] = correlation_function_statistics(C[key][wat], ci=0.95, tmin=60, nbootstrap=500)
        labels.append(wat)
        taus.append(tau_mle)
        taus_low.append(tau_low)
        taus_high.append(tau_high)
        Ps.append(P_mle)
        Ps_low.append(P_low)
        Ps_high.append(P_high)
        
# Plot MLE correlation function and exponential fit
fig = plt.figure(figsize=[2.75,4])
width = 0.7
edgecolor = '#cc0099'
facecolor = '#dddddd'
linewidth = 1.5
linestyles = ['-', '--']

# lifetimes
plt.subplot(2,1,1)
plt.hold(True)
for index in range(len(labels)):
    linestyle = linestyles[index % len(linestyles)]
    plt.bar(index+0.5, taus[index], width, edgecolor=edgecolor, facecolor=facecolor, linestyle=linestyle, linewidth=linewidth)
    plt.plot((index+width/2+0.5) * np.array([1, 1]), [taus_low[index], taus_high[index]], 'k-' )
plt.xticks([])
sns.despine()
plt.tight_layout()
plt.ylabel('correlation time (ns)');

# populations
plt.subplot(2,1,2)
width = 0.7
plt.hold(True)
for index in range(len(labels)):
    linestyle = linestyles[index % len(linestyles)]
    plt.bar(index+0.5, 100.*Ps[index], width, edgecolor=edgecolor, facecolor=facecolor, linestyle=linestyle, linewidth=linewidth)
    plt.plot((index+width/2+0.5) * np.array([1, 1]), [100.*Ps_low[index], 100.*Ps_high[index]], 'k-')

plt.xticks(np.arange(6) + width/2. + 0.5, labels)
sns.despine()
plt.ylabel('population (%)');

fontsize=9
plt.text((2-0.5)/2.+0.5, -10, mutants[0], horizontalalignment='center', fontsize=fontsize);
plt.text(2+(2-0.5)/2.+0.5, -10, mutants[1], horizontalalignment='center', fontsize=fontsize);
plt.text(4+(2-0.5)/2.+0.5, -10, mutants[2], horizontalalignment='center', fontsize=fontsize);

plt.tight_layout()
plt.savefig('Fig-3C.pdf')

# %%
# Analyze alphaC helix
def retrieve_alphaC_data(key):
    """
    Compile all available alphaC RMSD data.

    Parameters
    ----------
    key : str
        The key into 'simulations' to identify projects and RUNs associated with the simulation data.

    Returns
    -------
    rmsds : np.array shape (ntrajs, nframes)
        RMSDs
    """
    print("Retrieving data for '%s'..." % key)
    rmsds = list()
    rmsd_basepath = 'C-helix-analysis'
    for (project,run) in simulations[key]:
        run_lowercase = run.lower()
        rmsds.append( np.load(os.path.join(rmsd_basepath, '%(project)s-%(run_lowercase)s-alphaC-rmsd.npy') % vars()) )
    rmsds = np.vstack(rmsds) * 10 # angstroms
    # Squeeze out rows that are just None
    rmsds = squeeze_empty_trajectories(rmsds)
    return rmsds

# %%
rmsds = retrieve_alphaC_data('-Tpx2 WT')
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 0 empty trajectories

# %%
fig = plt.figure(figsize=[5,3])
ns_per_frame = 0.250
tvec = np.arange(2000) * ns_per_frame
plt.plot(tvec, rmsds.T);
plt.xlabel('time (ns)');
plt.ylabel('$\\alpha$C helix CA RMSD ($\\AA$)');

# %%
# Histogram in blocks
nframes = 2000
blocksize = 40 # number of frames
nblocks = nframes / blocksize
tblocks = (np.arange(nblocks) + 0.5) * blocksize * ns_per_frame
nbins = 20
bins = np.linspace(0, 15.0, nbins+1)

fig = plt.figure(figsize=[10,6])

for (col, mutant) in enumerate(['WT', 'Q185L']):
    for (row, tpx2) in enumerate(['-Tpx2', '+Tpx2']):
        plt.subplot(2,2, 2*row + col + 1)
        name = '%s %s' % (tpx2, mutant)
        rmsds = retrieve_alphaC_data(name)
        print(rmsds.shape)
        rmsd_density = np.zeros([nblocks,nbins], np.float32)
        for block in range(nblocks):
            frames = range(block*blocksize, (block+1)*blocksize)
            block_rmsds = rmsds[:,frames].flatten()
            # Filter out missing frames (which have negative RMSDs)
            block_rmsds = block_rmsds[block_rmsds >= 0.0]
            # Bin RMSDs
            [counts, _] = np.histogram(block_rmsds, bins=bins) 
            rmsd_density[block,:] = counts / float(len(block_rmsds))
        plt.imshow(rmsd_density.T, origin='lower', extent=[0, nframes*ns_per_frame, 0, nbins], aspect='10')
        plt.xlabel('time (ns)');
        plt.ylabel('$\\alpha$C helix CA RMSD ($\\AA$)');
        plt.title(name)
        
plt.tight_layout()
plt.savefig('alphaC-RMSD.pdf')
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 0 empty trajectories
# (250, 2000)
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 0 empty trajectories
# (250, 2000)
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 0 empty trajectories
# (50, 2000)
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 0 empty trajectories
# (50, 2000)

# %%
# Histogram for equilibrated region
nframes = 2000
tindices = range(500,2000)
nbins = 50
bins = np.linspace(0, 15.0, nbins+1)
bin_centers = (bins[0:nbins] + bins[1:(nbins+1)])/2.0
fig = plt.figure(figsize=[4,3])
plt.hold(True)

labels = list()
for (col, mutant) in enumerate(['WT', 'Q185L']):
    for (row, tpx2) in enumerate(['-Tpx2', '+Tpx2']):
        name = '%s %s' % (tpx2, mutant)
        rmsds = retrieve_alphaC_data(name)
        rmsds = rmsds.flatten()
        rmsds = rmsds[rmsds >= 0.0]
        [counts, _] = np.histogram(rmsds, bins=bins) 
        densities = counts / float(len(rmsds))
        plt.plot(bin_centers, densities, '-')
        #sns.distplot(rmsds)
        labels.append(name)
        
        
plt.legend(labels);
plt.xlabel('$\\alpha$C helix CA RMSD ($\\AA$)');
plt.ylabel('probability')
plt.yticks([]);

plt.tight_layout()
plt.savefig('alphaC-RMSD-histogram.pdf')
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 0 empty trajectories
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 0 empty trajectories

# %%
X = retrieve_alphaC_data('-Tpx2 WT')
Y = retrieve_alphaC_data('-Tpx2 Q185L')
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 0 empty trajectories

# %%
X
# Out:
# array([[ 1.47878814,  1.31819487,  1.39431381, ...,  6.68933773,
#          6.15265465,  6.47182751],
#        [ 1.39213181,  1.30722475,  1.69670916, ...,  2.963166  ,
#          2.9246707 ,  3.54662919],
#        [ 0.88522935,  1.27913582,  1.10302794, ...,  4.15741014,
#          4.42240477,  4.32694817],
#        ...,
#        [ 1.59372866,  1.63379908,  1.58899009, ...,  3.70481753,
#          3.6023581 ,  3.50969291],
#        [ 1.26272416,  1.44138741,  1.31087971, ...,  7.28516626,
#          7.34322166,  7.25610781],
#        [ 1.20056653,  1.20553005,  1.3798548 , ...,  4.5851202 ,
#          4.91135883,  5.3207922 ]], dtype=float32)

# %%
# Retrieve RMSD and water site data for -Tpx2 Q185L mutant to see if C-helix RMSD correlates with water occupancy
key = '-Tpx2 Q185L'
rmsd = retrieve_alphaC_data(key)
print(rmsd.shape)
[W1, W2] = retrieve_data(key)
print(W1.shape)
# Out:
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 0 empty trajectories
# (50, 2000)
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# (50, 2000)

# %%
# Try a simple correlation of water occupancy and RMSD averaged over temporal blocks
[ntrajs, nframes] = rmsd.shape
blocksize = 60 # number of frames in block
nblocks = nframes / blocksize

def plot_water_occupancy_vs_alphaC_RMSD(wat, W):
    Chelix_rmsds = list()
    water_occupancies = list()
    for traj in range(ntrajs):
        for block in range(nblocks):
            frames = range(block*blocksize, (block+1)*blocksize)
            block_rmsds = rmsd[traj,frames]
            # filter those that aren't available
            block_rmsds = block_rmsds[block_rmsds >= 0]
            # skip blocks that aren't full
            if len(block_rmsds) != blocksize:
                continue
            # get water occupancies
            block_occupancies = [ (len(s)>0) for s in W[traj,frames] if (s!=None) ]
            # skip blocks that aren't full
            if len(block_occupancies) != blocksize:
                continue
            # store
            Chelix_rmsds.append(np.mean(block_rmsds))
            water_occupancies.append(np.mean(block_occupancies))
    Chelix_rmsds = np.array(Chelix_rmsds)
    water_occupancies = np.array(water_occupancies)
    plt.plot(Chelix_rmsds, water_occupancies*100, '.');
    plt.xlabel('$\\alpha$C helix CA RMSD ($\\AA$)');
    plt.ylabel('water occupancy (%%)');
    plt.title('%s %s : %d blocks of %.1f ns/block analyzed' % (key, wat, len(water_occupancies), blocksize*ns_per_frame))
    sns.despine()
    plt.xticks([0,2,4,6,8,10,12])
    plt.yticks([0,20,40,60,80,100])
    plt.axis([0, 12, 0, 100])

sns.set_style("ticks")
fig = plt.figure(figsize=[10,8]);

# Retrieve RMSD and water site data for -Tpx2 Q185L mutant to see if C-helix RMSD correlates with water occupancy
key = '-Tpx2 WT'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(2,2,1)
plot_water_occupancy_vs_alphaC_RMSD('W1', W1)
plt.subplot(2,2,2)
plot_water_occupancy_vs_alphaC_RMSD('W2', W2)

key = '+Tpx2 WT'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(2,2,3)
plot_water_occupancy_vs_alphaC_RMSD('W1', W1)
plt.subplot(2,2,4)
plot_water_occupancy_vs_alphaC_RMSD('W2', W2)

plt.tight_layout()
plt.savefig('water-occupancy-vs-Chelix-RMSD-WT.pdf')
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories

# %%
# Correlate C[t] with average trajectory occupancy
[ntrajs, nframes] = rmsd.shape
blocksize = 60 # number of frames in block
nblocks = nframes / blocksize

W = W1

Chelix_rmsds = list()
water_occupancies = list()
for traj in range(ntrajs):
    for block in range(nblocks):
        frames = range(block*blocksize, (block+1)*blocksize)
        block_rmsds = rmsd[traj,frames]
        # filter those that aren't available
        block_rmsds = block_rmsds[block_rmsds >= 0]
        # skip blocks that aren't full
        if len(block_rmsds) != blocksize:
            continue
        # get water occupancies
        block_occupancies = [ (len(s)>0) for s in W[traj,frames] if (s!=None) ]
        # skip blocks that aren't full
        if len(block_occupancies) != blocksize:
            continue
        # compute longest single water occupancy
        waters = { w : 0 for s in W[traj,frames] for w in s if (s!=None) }
        for s in W[traj,frames]:
            if s == None:
                continue
            for w in s:
                waters[w] += 1
        if len(waters) == 0:
            largest_occupancy = 0.0
        else:
            largest_occupancy = max(waters.values()) / float(blocksize)                
        # store
        Chelix_rmsds.append(np.mean(block_rmsds))
        water_occupancies.append(largest_occupancy)
Chelix_rmsds = np.array(Chelix_rmsds)
water_occupancies = np.array(water_occupancies)

print('%d blocks analyzed' % len(Chelix_rmsds))
fig = plt.figure(figsize=[6,6]);
plt.plot(Chelix_rmsds, water_occupancies*100, '.');
plt.xlabel('$\\alpha$C helix CA RMSD ($\\AA$)');
plt.ylabel('water occupancy (%%)');
# Out:
# 6781 blocks analyzed

# %%
# Try a simple correlation of water occupancy and RMSD averaged over temporal blocks
blocksize = 60 # number of frames in block
nblocks = nframes / blocksize

def plot_largest_water_occupancy_vs_alphaC_RMSD(wat, W, rmsd):
    [ntrajs, nframes] = rmsd.shape
    Chelix_rmsds = list()
    water_occupancies = list()
    for traj in range(ntrajs):
        for block in range(nblocks):
            frames = range(block*blocksize, (block+1)*blocksize)
            block_rmsds = rmsd[traj,frames]
            # filter those that aren't available
            block_rmsds = block_rmsds[block_rmsds >= 0]
            # skip blocks that aren't full
            if len(block_rmsds) != blocksize:
                continue
            # get water occupancies
            block_occupancies = [ (len(s)>0) for s in W[traj,frames] if (s!=None) ]
            # skip blocks that aren't full
            if len(block_occupancies) != blocksize:
                continue
            # compute longest single water occupancy
            waters = { w : 0 for s in W[traj,frames] for w in s if (s!=None) }
            for s in W[traj,frames]:
                if s == None:
                    continue
                for w in s:
                    waters[w] += 1
            if len(waters.values()) > 0:
                largest_occupancy = max(waters.values()) / float(blocksize)                
            else:
                largest_occupancy = 0
            # store
            Chelix_rmsds.append(np.mean(block_rmsds))
            water_occupancies.append(largest_occupancy)
    Chelix_rmsds = np.array(Chelix_rmsds)
    water_occupancies = np.array(water_occupancies)
    plt.plot(Chelix_rmsds, water_occupancies*100, '.');
    plt.xlabel('$\\alpha$C helix CA RMSD ($\\AA$)');
    plt.ylabel('water occupancy (%)');
    plt.title('%s %s : %d blocks of %.1f ns/block analyzed' % (key, wat, len(water_occupancies), blocksize*ns_per_frame))
    sns.despine()
    plt.xticks([0,2,4,6,8,10,12])
    plt.yticks([0,20,40,60,80,100])
    plt.axis([0, 12, 0, 100])

sns.set_style("ticks")
fig = plt.figure(figsize=[10,8]);

# Retrieve RMSD and water site data for -Tpx2 Q185L mutant to see if C-helix RMSD correlates with water occupancy
key = '-Tpx2 Q185L'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(2,2,1)
plot_largest_water_occupancy_vs_alphaC_RMSD('W1', W1, rmsd)
plt.subplot(2,2,2)
plot_largest_water_occupancy_vs_alphaC_RMSD('W2', W2, rmsd)

key = '+Tpx2 Q185L'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(2,2,3)
plot_largest_water_occupancy_vs_alphaC_RMSD('W1', W1, rmsd)
plt.subplot(2,2,4)
plot_largest_water_occupancy_vs_alphaC_RMSD('W2', W2, rmsd)
plt.tight_layout()
plt.savefig('largest-water-occupancy-vs-Chelix-RMSD-Q185L.pdf')
# Out:
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 0 empty trajectories
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 0 empty trajectories
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories

# %%
# Plot histograms for no waters and waters in site separately
[ntrajs, nframes] = rmsd.shape

def plot_rmsd_histograms(wat, W, rmsd):
    Chelix_rmsds_water_present = list()
    Chelix_rmsds_water_absent = list()
    for traj in range(ntrajs):
        for frame in range(nframes):
            # skip frames with no data
            if W[traj,frame] is None:
                continue
            if rmsd[traj,frame] < 0:
                continue
            # store RMSD
            if len(W[traj,frame]) > 0:
                Chelix_rmsds_water_present.append(rmsd[traj,frame])
            else:
                Chelix_rmsds_water_absent.append(rmsd[traj,frame])

    Chelix_rmsds_water_present = np.array(Chelix_rmsds_water_present)
    Chelix_rmsds_water_absent = np.array(Chelix_rmsds_water_absent)

    nbins = 50
    bins = np.linspace(0, 15.0, nbins+1)
    bin_centers = (bins[0:nbins] + bins[1:(nbins+1)])/2.0
    
    [P_present, _] = np.histogram(Chelix_rmsds_water_present, bins)
    P_present = P_present / float(P_present.sum())
    [P_absent, _] = np.histogram(Chelix_rmsds_water_absent, bins)
    P_absent = P_absent / float(P_absent.sum())
    
    plt.hold(True)
    plt.plot(bin_centers, P_present, 'k-');
    plt.plot(bin_centers, P_absent, 'k--');
    plt.legend(['%s %s occupied' % (key, wat), '%s %s unoccupied' % (key, wat)]);
    plt.xlabel('$\\alpha$C helix CA RMSD ($\\AA$)');
    sns.despine()
    #plt.xticks([0,2,4,6,8,10,12,14,16])
    #plt.axis([0, 12, 0, 100])

sns.set_style("ticks")
fig = plt.figure(figsize=[10,8]);

# Retrieve RMSD and water site data for -Tpx2 Q185L mutant to see if C-helix RMSD correlates with water occupancy
key = '-Tpx2 Q185L'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(2,2,1)
plot_rmsd_histograms('W1', W1, rmsd)
plt.subplot(2,2,2)
plot_rmsd_histograms('W2', W2, rmsd)

key = '+Tpx2 Q185L'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(2,2,3)
plot_rmsd_histograms('W1', W1, rmsd)
plt.subplot(2,2,4)
plot_rmsd_histograms('W2', W2, rmsd)
plt.tight_layout()
plt.savefig('RMSD-water-histogram-Q185L.pdf')
# Out:
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 0 empty trajectories
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 0 empty trajectories
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories

# %%
# Plot histograms for long-lived waters and short-lived waters in site separately
tau = 80 # lag time to verify that water is still there (20 ns)

def plot_long_lived_rmsd_histograms(wat, W, rmsd):
    [ntrajs, nframes] = rmsd.shape

    Chelix_rmsds_water_present = list()
    Chelix_rmsds_water_absent = list()
    for traj in range(ntrajs):
        for frame in range(nframes-tau):
            # skip frames with no data
            if (W[traj,frame] is None) or (W[traj,frame+tau] is None):
                continue
            if (rmsd[traj,frame] < 0) or (rmsd[traj,frame+tau] < 0):
                continue
            # store RMSD if water is there at times t0 and t0+tau
            if len(W[traj,frame].intersection(W[traj,frame+tau])) > 0:
                Chelix_rmsds_water_present.append(rmsd[traj,frame])
            else:
                Chelix_rmsds_water_absent.append(rmsd[traj,frame])

    Chelix_rmsds_water_present = np.array(Chelix_rmsds_water_present)
    Chelix_rmsds_water_absent = np.array(Chelix_rmsds_water_absent)

    nbins = 50
    bins = np.linspace(0, 15.0, nbins+1)
    bin_centers = (bins[0:nbins] + bins[1:(nbins+1)])/2.0
    
    [P_present, _] = np.histogram(Chelix_rmsds_water_present, bins)
    P_present = P_present / float(P_present.sum())
    [P_absent, _] = np.histogram(Chelix_rmsds_water_absent, bins)
    P_absent = P_absent / float(P_absent.sum())
    
    plt.hold(True)
    plt.plot(bin_centers, P_present, 'k-');
    plt.plot(bin_centers, P_absent, 'k--');
    plt.legend(['%s %s long-lived' % (key, wat), '%s %s short-lived' % (key, wat)]);
    plt.xlabel('$\\alpha$C helix CA RMSD ($\\AA$)');
    plt.axis([0, 6, 0, max(P_present.max(), P_absent.max())])
    sns.despine()
    #plt.xticks([0,2,4,6,8,10,12,14,16])
    #plt.axis([0, 12, 0, 100])

sns.set_style("ticks")
fig = plt.figure(figsize=[10,8]);

# Retrieve RMSD and water site data for -Tpx2 Q185L mutant to see if C-helix RMSD correlates with water occupancy
key = '-Tpx2 WT'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(2,2,1)
plot_long_lived_rmsd_histograms('W1', W1, rmsd)
plt.subplot(2,2,2)
plot_long_lived_rmsd_histograms('W2', W2, rmsd)

key = '+Tpx2 WT'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(2,2,3)
plot_long_lived_rmsd_histograms('W1', W1, rmsd)
plt.subplot(2,2,4)
plot_long_lived_rmsd_histograms('W2', W2, rmsd)
plt.tight_layout()
plt.savefig('RMSD-long-lived-water-histogram-WT.pdf')
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories

# %%
# Plot histograms for long-lived coupled waters (2 in W1 and W2) and short-lived waters in site separately
tau = 80 # lag time to verify that water is still there (20 ns)

def plot_long_lived_coupled_rmsd_histograms(W1, W2, rmsd):
    [ntrajs, nframes] = rmsd.shape

    Chelix_rmsds_water_present = list()
    Chelix_rmsds_water_absent = list()
    for traj in range(ntrajs):
        for frame in range(nframes-tau):
            # skip frames with no data
            if (W1[traj,frame] is None) or (W2[traj,frame+tau] is None):
                continue
            if (rmsd[traj,frame] < 0) or (rmsd[traj,frame+tau] < 0):
                continue
            # store RMSD if water is there at times t0 and t0+tau
            if len(set.union(W1[traj,frame],W2[traj,frame]).intersection(set.union(W1[traj,frame+tau],W2[traj,frame+tau]))) > 2:
                Chelix_rmsds_water_present.append(rmsd[traj,frame])
            else:
                Chelix_rmsds_water_absent.append(rmsd[traj,frame])

    Chelix_rmsds_water_present = np.array(Chelix_rmsds_water_present)
    Chelix_rmsds_water_absent = np.array(Chelix_rmsds_water_absent)

    nbins = 50
    bins = np.linspace(0, 15.0, nbins+1)
    bin_centers = (bins[0:nbins] + bins[1:(nbins+1)])/2.0
    
    [P_present, _] = np.histogram(Chelix_rmsds_water_present, bins)
    P_present = P_present / float(P_present.sum())
    [P_absent, _] = np.histogram(Chelix_rmsds_water_absent, bins)
    P_absent = P_absent / float(P_absent.sum())
    
    plt.hold(True)
    plt.plot(bin_centers, P_present, 'k-');
    plt.plot(bin_centers, P_absent, 'k--');
    plt.legend(['%s long-lived' % (key), '%s short-lived' % (key)]);
    plt.xlabel('$\\alpha$C helix CA RMSD ($\\AA$)');
    plt.axis([0, 15, 0, max(P_present.max(), P_absent.max())])
    sns.despine()
    #plt.xticks([0,2,4,6,8,10,12,14,16])
    #plt.axis([0, 12, 0, 100])

sns.set_style("ticks")
fig = plt.figure(figsize=[10,8]);

# Retrieve RMSD and water site data for -Tpx2 Q185L mutant to see if C-helix RMSD correlates with water occupancy
key = '-Tpx2 WT'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(1,2,1)
plot_long_lived_coupled_rmsd_histograms(W1, W2, rmsd)

key = '+Tpx2 WT'
rmsd = retrieve_alphaC_data(key)
[W1, W2] = retrieve_data(key)
plt.subplot(1,2,2)
plot_long_lived_coupled_rmsd_histograms(W1, W2, rmsd)

plt.tight_layout()
plt.savefig('RMSD-long-lived-water-histogram-2waters-WT.pdf')
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 0 empty trajectories
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories

# %%
# Examine correlation among water sites
mutants = ['WT', 'Q185L', 'Q185M']
for mutant in mutants:
    for tpx2 in ['-Tpx2', '+Tpx2']:
        key = '%s %s' % (tpx2, mutant)
        [W1, W2] = retrieve_data(key)
        # Convert to binary occupancies: 1 if any water present, 0 if no water present
        [N_W1, N_W2, N_W1W2, N] = [0., 0., 0., 0.]
        for traj in range(ntrajs):
            for frame in range(nframes):
                # Skip missing data
                if (W1[traj,frame] is None) or (W2[traj,frame] is None):
                    continue
                # Accumulate counts
                W1_present = len(W1[traj,frame])>0
                W2_present = len(W2[traj,frame])>0
                N_W1 += W1_present
                N_W2 += W2_present
                N_W1W2 += (W1_present and W2_present)
                N += 1.0
        print('%s : P(W2|W1) = %8.5f | P(W1|W2) = %8.5f (N = %8d)' % (key, N_W1W2/N_W1, N_W1W2/N_W2, N))
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# -Tpx2 WT : P(W2|W1) =  0.67693 | P(W1|W2) =  0.91840 (N =   100000)
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# +Tpx2 WT : P(W2|W1) =  0.79375 | P(W1|W2) =  0.89928 (N =   100000)
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# -Tpx2 Q185L : P(W2|W1) =  0.41554 | P(W1|W2) =  0.93504 (N =    83600)
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# +Tpx2 Q185L : P(W2|W1) =  0.64615 | P(W1|W2) =  0.95058 (N =    64520)
# Retrieving data for '-Tpx2 Q185M'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# -Tpx2 Q185M : P(W2|W1) =  0.52197 | P(W1|W2) =  0.88845 (N =    76880)
# Retrieving data for '+Tpx2 Q185M'...
# ...

# %%
# Check whether the same water can ever appear in both W1 and W2 criteria 
mutants = ['WT', 'Q185L', 'Q185M']
for mutant in mutants:
    for tpx2 in ['-Tpx2', '+Tpx2']:
        key = '%s %s' % (tpx2, mutant)
        [W1, W2] = retrieve_data(key)
        # Convert to binary occupancies: 1 if any water present, 0 if no water present
        [N_wat, N_same, N] = [0., 0., 0.]
        for traj in range(ntrajs):
            for frame in range(nframes):
                # Skip missing data
                if (W1[traj,frame] is None) or (W2[traj,frame] is None):
                    continue
                # Accumulate counts
                same_W_present = len(W1[traj,frame].intersection(W2[traj,frame]))>0
                if same_W_present:
                    N_wat += len(W1[traj,frame].union(W2[traj,frame]))
                N_same += same_W_present
                N += 1.0
        print('%-10s : same wat present in W1/W2 in %6d / %6d frames (%4.1f %%); avg num wat meeting W1 or W2 criteria %.3f' % (key, N_same, N, N_same/N*100, N_wat/N_same))
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# -Tpx2 WT   : same wat present in W1/W2 in  25703 / 100000 frames (25.7 %); avg num wat meeting W1 or W2 criteria 1.838
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# +Tpx2 WT   : same wat present in W1/W2 in  15073 / 100000 frames (15.1 %); avg num wat meeting W1 or W2 criteria 1.742
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# -Tpx2 Q185L : same wat present in W1/W2 in  20026 /  83600 frames (24.0 %); avg num wat meeting W1 or W2 criteria 1.867
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# +Tpx2 Q185L : same wat present in W1/W2 in  25588 /  64520 frames (39.7 %); avg num wat meeting W1 or W2 criteria 1.978
# Retrieving data for '-Tpx2 Q185M'...
# ...

# %%
# How much simulation data do we have?
mutants = ['WT', 'Q185L', 'Q185M']
for mutant in mutants:
    for tpx2 in ['-Tpx2', '+Tpx2']:
        key = '%s %s' % (tpx2, mutant)
        [W1, W2] = retrieve_data(key)
        [ntrajs,nframes] = W1.shape
        nframes_total = 0.
        for traj in range(ntrajs):
            for frame in range(nframes):
                # Skip missing data
                if (W1[traj,frame] is None) or (W2[traj,frame] is None):
                    continue        
                nframes_total += 1.
        print('-%10s : %5d trajectories, %8d frames total, %8.3f ns aggregate' % (key, ntrajs, nframes_total, nframes_total * ns_per_frame))
# Out:
# Retrieving data for '-Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# -  -Tpx2 WT :   250 trajectories,   416919 frames total, 104229.750 ns aggregate
# Retrieving data for '+Tpx2 WT'...
# Squeezed out 1000 empty trajectories
# Squeezed out 1000 empty trajectories
# -  +Tpx2 WT :   250 trajectories,   411956 frames total, 102989.000 ns aggregate
# Retrieving data for '-Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# --Tpx2 Q185L :    50 trajectories,    83600 frames total, 20900.000 ns aggregate
# Retrieving data for '+Tpx2 Q185L'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# -+Tpx2 Q185L :    50 trajectories,    64520 frames total, 16130.000 ns aggregate
# Retrieving data for '-Tpx2 Q185M'...
# Squeezed out 200 empty trajectories
# Squeezed out 200 empty trajectories
# --Tpx2 Q185M :    50 trajectories,    76880 frames total, 19220.000 ns aggregate
# ...
